# %% [markdown]
# <a href="https://colab.research.google.com/github/deepakgowtham/Datascience_Basics/blob/main/Visualizations/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Basics

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# creates an empty figure and axes
fig, ax= plt.subplots()
plt.show()

# %%
# !wget https://assets.datacamp.com/production/repositories/3634/datasets/6fd451508ecce0d63354fad86704236592eed8ca/seattle_weather.csv
# !wget https://assets.datacamp.com/production/repositories/3634/datasets/e76b460b41dc7ff286d78246daf3a8c324cb5587/austin_weather.csv
# Out:
# --2020-11-30 09:49:15--  https://assets.datacamp.com/production/repositories/3634/datasets/6fd451508ecce0d63354fad86704236592eed8ca/seattle_weather.csv
# Resolving assets.datacamp.com (assets.datacamp.com)... 104.22.58.211, 172.67.39.105, 104.22.59.211
# Connecting to assets.datacamp.com (assets.datacamp.com)|104.22.58.211|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 87768 (86K) [text/csv]
# Saving to: ‘seattle_weather.csv’
#
# seattle_weather.csv 100%[===================>]  85.71K  --.-KB/s    in 0.008s
#
# 2020-11-30 09:49:15 (11.1 MB/s) - ‘seattle_weather.csv’ saved [87768/87768]
#
# --2020-11-30 09:49:15--  https://assets.datacamp.com/production/repositories/3634/datasets/e76b460b41dc7ff286d78246daf3a8c324cb5587/austin_weather.csv
# Resolving assets.datacamp.com (assets.datacamp.com)... 104.22.58.211, 172.67.39.105, 104.22.59.211
# Connecting to assets.datacamp.com (assets.datacamp.com)|104.22.58.211|:443... connected.
# ...

# %%
import pandas as pd
seattle_weather_full =pd.read_csv('/content/seattle_weather.csv')
austin_weather= pd.read_csv('/content/austin_weather.csv')

# %%
seattle_weather= seattle_weather_full[seattle_weather_full.STATION=='USW00094290']

# %%
seattle_weather.shape
# Out:
# (204, 80)

# %%
austin_weather.shape
# Out:
# (12, 67)

# %% [markdown]
# ## Methods of axes object
# - Adding data to a figure is done by calling methods of the Axes object.
# - we will use the **plot** method to add data about rainfall in two American cities: Seattle, WA and Austin, TX.

# %%
plt.clf()
fig, ax= plt.subplots()
ax.plot(austin_weather["DATE"], austin_weather['MLY-PRCP-NORMAL'])
plt.show()

# %%
## one more series of data can also be added to the current axes object
plt.clf()
fig, ax= plt.subplots()
ax.plot(austin_weather["DATE"], austin_weather['MLY-PRCP-NORMAL'])
ax.plot(seattle_weather["DATE"], seattle_weather['MLY-PRCP-NORMAL'])
plt.show()

# %% [markdown]
# ## Customising the plots
# - marker --> https://matplotlib.org/api/markers_api.html
# - linestyle --> https://matplotlib.org/gallery/lines_bars_and_markers/line_styles_reference.html
# - color -->
#
# - ax.set_xlabel
# - ax.set_ylabel
# - ax.set_title
# -   ax.tick_params('y', colors=color)
# - ax.set_xticklabels(df.index, rotatation=90)

# %%
plt.clf()
fig, ax= plt.subplots()
ax.plot(seattle_weather["DATE"], seattle_weather["MLY-PRCP-NORMAL"], color='b', marker='o',linestyle='--')
ax.plot(austin_weather["DATE"], austin_weather["MLY-PRCP-NORMAL"], color='r', marker='v',linestyle='--')
ax.set_xlabel('Time (months)')
ax.set_ylabel('Precipitation (inches)')
ax.set_title("Weather patterns in Austin and Seattle")
plt.show()

# %% [markdown]
# ### size
# If you already have the figure object use:
# - fig.set_figheight(15)
# - fig.set_figwidth(15)
#
# - fig.set_size_inches((5,3)
# - fig, ax= plt.subplots(figsize=(13,5))

# %%
import matplotlib.pyplot as plt
import numpy as np

f = plt.figure(figsize=(10,3))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)
x = np.linspace(0,4,1000)
ax.plot(x, np.sin(x))
ax2.plot(x, np.cos(x), 'r:')

# %% [markdown]
# ### Style
# - plt.style.use('ggplot')
# - plt.style.use('default')
# - https://matplotlib.org/gallery/style_sheets/style_sheets_reference.html

# %%
plt.style.use('ggplot')
fig, ax= plt.subplots()
ax.plot(seattle_weather["DATE"], seattle_weather["MLY-TAVG-NORMAL"])
plt.show()

# %%
plt.style.use('Solarize_Light2')
fig, ax= plt.subplots()
ax.plot(austin_weather["DATE"], austin_weather["MLY-TAVG-NORMAL"])
plt.show()

# %%
plt.style.use('default')

# %% [markdown]
# ## Small multiples
#  - sub plot of multiple plots
#  - fig, ax= plt.subplot(2,1)
#  - The first argument is the number of rows in the array of Axes objects generate and the second argument is the number of columns
#  - now axes object becomes an array of 2,1
#  - as in this case if x axis is 1d it can share a common data
#  - When creating small multiples, it is often preferable to make sure that the different plots are displayed with the same scale used on the y-axis. This can be configured by setting the sharey key-word to True
#  - **sharey=True** gets a common y range

# %%
plt.clf()
fig, ax= plt.subplots(2,2, figsize=(13,5))

ax[0,0].plot(seattle_weather['DATE'], seattle_weather['MLY-PRCP-NORMAL'])
ax[0,1].plot(seattle_weather['DATE'], seattle_weather['MLY-TAVG-NORMAL'])
ax[1,0].plot(austin_weather['DATE'], austin_weather['MLY-PRCP-NORMAL'])
ax[1,1].plot(austin_weather['DATE'], austin_weather['MLY-TAVG-NORMAL'])
plt.show()

# %%
plt.clf()
fig, ax = plt.subplots(2, 1, sharey=True, figsize=(13,5))
ax[0].plot(seattle_weather['DATE'], seattle_weather['MLY-PRCP-NORMAL'], color = 'b')
ax[0].plot(seattle_weather['DATE'], seattle_weather['MLY-PRCP-25PCTL'], color = 'b', linestyle = '--')
ax[0].plot(seattle_weather['DATE'], seattle_weather['MLY-PRCP-75PCTL'], color = 'b', linestyle = '--')

ax[1].plot(austin_weather['DATE'], austin_weather['MLY-PRCP-NORMAL'], color = "r")
ax[1].plot(austin_weather['DATE'], austin_weather['MLY-PRCP-25PCTL'], color = "r", linestyle = '--')
ax[1].plot(austin_weather['DATE'], austin_weather['MLY-PRCP-75PCTL'], color = "r", linestyle = '--')

plt.show()

# %% [markdown]
# # Plotting Timeseries

# %%
# !wget https://assets.datacamp.com/production/repositories/3634/datasets/411add3f8570d5adf891127fd64095020210711b/climate_change.csv
# Out:
# --2020-11-30 10:04:31--  https://assets.datacamp.com/production/repositories/3634/datasets/411add3f8570d5adf891127fd64095020210711b/climate_change.csv
# Resolving assets.datacamp.com (assets.datacamp.com)... 104.22.58.211, 172.67.39.105, 104.22.59.211
# Connecting to assets.datacamp.com (assets.datacamp.com)|104.22.58.211|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16211 (16K) [text/csv]
# Saving to: ‘climate_change.csv’
#
# climate_change.csv  100%[===================>]  15.83K  --.-KB/s    in 0s
#
# 2020-11-30 10:04:31 (90.7 MB/s) - ‘climate_change.csv’ saved [16211/16211]

# %%
climate_change = pd.read_csv('/content/climate_change.csv', parse_dates=True, index_col='date')

# %%
climate_change.shape
# Out:
# (706, 2)

# %%
plt.clf()
fig, ax= plt.subplots(figsize=(13,5))
ax.plot(climate_change.index, climate_change.relative_temp)
ax.set_xlabel('Time')
ax.set_ylabel('Relative temperature (Celsius)')
plt.show()

# %%
seventies=climate_change['1970-01-01':'1979-12-31']
plt.clf()
fig, ax= plt.subplots(figsize=(13,5))
ax.plot(seventies.index, seventies['co2'])
plt.show()

# %% [markdown]
# ## Multivariate with two yaxis
# Plotting two variables with different y range on same scale will not be helpful to view to use two y scales using twinx method
# - twinx method --> ax2= ax.tiwnx()
# - color code yaxis labels
# - color code yaxis ticks -->ax.tick_params('y', colors='red')

# %%
plt.clf()
fig, ax= plt.subplots(figsize=(13,5))
ax.plot(climate_change.index, climate_change.co2, color='blue')
ax.plot(climate_change.index, climate_change.relative_temp, color='red')
plt.show()

# %%
plt.clf()
fig, ax= plt.subplots(figsize=(13,5))
ax.plot(climate_change.index, climate_change.co2, color='blue')
ax2=ax.twinx()
ax2.plot(climate_change.index, climate_change.relative_temp, color='red')
plt.show()

# %%
def plot_timeseries(axes, x, y, color, xlabel, ylabel):

  # Plot the inputs x,y in the provided color
  axes.plot(x, y, color=color)

  # Set the x-axis label
  axes.set_xlabel(xlabel)

  # Set the y-axis label
  axes.set_ylabel(ylabel, color=color)

  # Set the colors tick params for y-axis
  axes.tick_params('y', colors=color)

# %%
#same code using function
fig, ax = plt.subplots()
plot_timeseries(ax, climate_change.index, climate_change['co2'], "blue", "Time (years)", "CO2 levels")
ax2 = ax.twinx()
plot_timeseries(ax2, climate_change.index, climate_change['relative_temp'], "red", "Time (years)", "Relative temperature (Celsius)")
plt.show()

# %% [markdown]
# ## Annotation
# - https://matplotlib.org/tutorials/text/annotations.html
# - https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.annotate.html#matplotlib.axes.Axes.annotate
# - ax2.annotate("text", <br />
#      xy=[pd.Timestamp('2015-10-06'),1], <br />
#      xytext=[pd.TImestamp('2008-10-06'),-0.2], <br />
#      arrowprops={})

# %%
fig, ax= plt.subplots( figsize=(13,5))
plot_timeseries(ax, climate_change.index, climate_change['co2'], "blue", "Time (years)", "CO2 levels")
ax2 = ax.twinx()
plot_timeseries(ax2, climate_change.index, climate_change['relative_temp'], "red", "Time (years)", "Relative temperature (Celsius)")

ax2.annotate('>1 degree', xy= [pd.Timestamp('2015-10-06'), 1], 
             xytext=[pd.Timestamp('2008-10-06'), -0.2],
             arrowprops={'arrowstyle': 'fancy', 'color':'black' })

plt.show()

# %% [markdown]
# # statistical plots

# %%
# !wget https://assets.datacamp.com/production/repositories/3634/datasets/ec663f9f509bf633d40932f65bd4cc51205689e2/medals_by_country_2016.csv
# Out:
# --2020-11-30 08:00:26--  https://assets.datacamp.com/production/repositories/3634/datasets/ec663f9f509bf633d40932f65bd4cc51205689e2/medals_by_country_2016.csv
# Resolving assets.datacamp.com (assets.datacamp.com)... 172.67.39.105, 104.22.59.211, 104.22.58.211
# Connecting to assets.datacamp.com (assets.datacamp.com)|172.67.39.105|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 193 [text/csv]
# Saving to: ‘medals_by_country_2016.csv’
#
# medals_by_country_2 100%[===================>]     193  --.-KB/s    in 0s
#
# 2020-11-30 08:00:27 (18.6 MB/s) - ‘medals_by_country_2016.csv’ saved [193/193]

# %%
medals= pd.read_csv('/content/medals_by_country_2016.csv', index_col=0)

# %%
medals.head()
# Out:
#                Bronze  Gold  Silver
# United States      67   137      52
# Germany            67    47      43
# Great Britain      26    64      55
# Russia             35    50      28
# China              35    44      30

# %% [markdown]
# ## Bar chart
#  - Categroical on x axis vs Numberical on y
#  - Value of variable in different conditions( categorical variable)
#  - ax.bar

# %%
plt.clf()
fig, ax =plt.subplots(figsize=(13,5))
ax.bar(medals.index, medals['Gold'])
ax.set_xticklabels(medals.index, rotation=45)
ax.set_ylabel('No of Medals')
plt.show()

# %% [markdown]
# ### Stacked bar chart
# - ax.bar(medals.index, medals['Gold'], label='Gold')
# - ax.bar(medals.index, medals['Silver'], bottom=medals['Gold'], label='Silver')
# - ax.bar(medals.index, medals['Bronze'], bottom=**medals["Gold"]+medals['Silver']**, label='Bronze')

# %%
plt.clf()
fig, ax =plt.subplots(figsize=(13,5))
ax.bar(medals.index, medals['Gold'], label='Gold')
ax.bar(medals.index, medals['Silver'], bottom=medals['Gold'], label='Silver')
ax.bar(medals.index, medals['Bronze'], bottom=medals["Gold"]+medals['Silver'], label='Bronze')
ax.set_xticklabels(medals.index, rotation=45)
ax.set_ylabel('No of Medals')
ax.legend()
plt.show()

# %%
# !wget https://assets.datacamp.com/production/repositories/3634/datasets/67d7344085ace400d612275b87738615698127a3/summer2016.csv
# Out:
# --2020-11-30 08:21:48--  https://assets.datacamp.com/production/repositories/3634/datasets/67d7344085ace400d612275b87738615698127a3/summer2016.csv
# Resolving assets.datacamp.com (assets.datacamp.com)... 104.22.59.211, 104.22.58.211, 172.67.39.105
# Connecting to assets.datacamp.com (assets.datacamp.com)|104.22.59.211|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 304007 (297K) [text/csv]
# Saving to: ‘summer2016.csv’
#
# summer2016.csv      100%[===================>] 296.88K  --.-KB/s    in 0.1s
#
# 2020-11-30 08:21:49 (1.97 MB/s) - ‘summer2016.csv’ saved [304007/304007]

# %%
summer2016= pd.read_csv('/content/summer2016.csv')

# %%
mens_rowing= summer2016[(summer2016['Sport']=='Rowing')  & ( summer2016['Sex']=='M') ]
mens_gymnastics= summer2016[(summer2016['Sport']=='Gymnastics')  & ( summer2016['Sex']=='M') ]

# %% [markdown]
# ### Univariate bars
# - Combine two bars

# %%
### bar
plt.clf()
fig, ax = plt.subplots(figsize=(13,5))
ax.bar('Rowing', mens_rowing['Height'].mean() )
ax.bar('Gymnastics', mens_gymnastics['Height'].mean())
plt.show()

# %% [markdown]
# ### Adding error bars

# %%
plt.clf()
fig, ax = plt.subplots(figsize=(13,5))
ax.bar('Rowing', mens_rowing['Height'].mean() , yerr=mens_rowing['Height'].std())
ax.bar('Gymnastics', mens_gymnastics['Height'].mean(), yerr= mens_gymnastics['Height'].std())
plt.show()

# %%
fig, ax = plt.subplots()

# Add Seattle temperature data in each month with error bars
ax.errorbar(seattle_weather['DATE'], seattle_weather['MLY-TAVG-NORMAL'], yerr= seattle_weather['MLY-TAVG-STDDEV'])

# Add Austin temperature data in each month with error bars
ax.errorbar(austin_weather['DATE'], austin_weather['MLY-TAVG-NORMAL'], yerr= austin_weather['MLY-TAVG-STDDEV']) 

# Set the y-axis label
ax.set_ylabel('Temperature (Fahrenheit)')

plt.show()

# %% [markdown]
# ## Histogram
# - Univaraite distribution of a continous variable
# - Entire distribution of values within a variable
# - ax.hist()

# %%
plt.clf()
fig, ax= plt.subplots(figsize=(13,5))
ax.hist(mens_rowing['Height'], label='Rowing')
ax.hist(mens_gymnastics['Height'], label='Gymnastics')
ax.set_xlabel('Height')
ax.set_ylabel('# of observations')
ax.legend()
plt.show()

# %% [markdown]
# #### Histogram customization and bins
# - bins -- list or a number
# - histype  --- step, bar

# %%
plt.clf()
fig, ax= plt.subplots(figsize=(13,5))
ax.hist(mens_rowing['Height'], label='Rowing', bins=[150, 160, 170, 180, 190, 200, 210], histtype='step')
ax.hist(mens_gymnastics['Height'], label='Gymnastics', bins=[150, 160, 170, 180, 190, 200, 210], histtype='step')
ax.set_xlabel('Height')
ax.set_ylabel('# of observations')
ax.legend()
plt.show()

# %% [markdown]
# ## Box Plot
# - categoical vs Continous

# %%
plt.clf()
fig, ax= plt.subplots(figsize=(12,5))
ax.boxplot([ mens_rowing['Height'], mens_gymnastics["Height"]])
ax.set_xticklabels(['Rowing', 'Gymnastics'])
ax.set_ylabel('Height(cm)')
plt.show()

# %% [markdown]
# ## scatter plot

# %%
fig, ax = plt.subplots()

ax.scatter(climate_change['co2'], climate_change['relative_temp'])
ax.set_xlabel('CO2 (ppm)')
ax.set_ylabel('Relative temperature (C)')
plt.show()

# %%
# index as color code 
fig, ax = plt.subplots()
ax.scatter(climate_change['co2'], climate_change['relative_temp'],c=climate_change.index)
ax.set_xlabel('co2 (ppm)')
ax.set_ylabel('Relative temperature (C)')

plt.show()

# %% [markdown]
# # Saving figures
# - fig.savefig('file.ext', quality =50)
# -  quality == compression between 1 to 100
# - dpi =300  -- dots per inch
